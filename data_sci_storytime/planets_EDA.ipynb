# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn')

# %%
planets = pd.read_excel('planets_moons.xlsx')
planets
# Out:
#          name    type  mass_1024kg  diameter_km  density_kg_m3  gravity_m_s2  \
# 0    Mercury   planet       0.3300       4879.0           5427           3.7
# 1      Venus   planet       4.8700      12104.0           5243           8.9
# 2      Earth   planet       5.9700      12756.0           5514           9.8
# 3       Moon     moon       0.0730       3475.0           3340           1.6
# 4       Mars   planet       0.6420       6792.0           3933           3.7
# 5    Jupiter   planet    1898.0000     142984.0           1326          23.1
# 6     Saturn   planet     568.0000     120536.0            687           9.0
# 7       Titan    moon       0.1260       5149.4           1882           1.4
# 8     Uranus   planet      86.8000      51118.0           1271           8.7
# 9    Neptune   planet     102.0000      49528.0           1638          11.0
# 10     Pluto    dwarf       0.0146       2370.0           2095           0.7
#
#     escape_vel_km_s  rotation_period_hr  day_len_hr  distance_from_sun_106 km  \
# 0               4.3              1407.6      4222.6                      57.9
# 1              10.4             -5832.5      2802.0                     108.2
# 2              11.2                23.9        24.0                     149.6
# 3               2.4               655.7       708.7                     149.6
# 4               5.0                24.6        24.7                     227.9
# 5              59.5                 9.9         9.9                     778.6
# 6              35.5                10.7        10.7                    1433.5
# 7               2.6               382.0       382.0                    1433.5
# 8              21.3               -17.2        17.2                    2872.5
# 9              23.5                16.1        16.1                    4495.1
# 10              1.3              -153.3       153.3                    5906.4
#
#     ...      H2       He     H2O      CH4     NH3     CO2     N2      O2  \
# 0   ...   0.220  0.06000       0  0.00000  0.0000  0.0000  0.000  0.4200
# 1   ...   0.000  0.00002   2e-05  0.00000  0.0000  0.9650  0.035  0.0000
# 2   ...   0.000  0.00000  0-0.04  0.00000  0.0000  0.0003  0.781  0.2090
# 3   ...   0.000  0.29000       0  0.00000  0.0000  0.0000  0.000  0.0000
# 4   ...   0.000  0.00000   3e-05  0.00000  0.0000  0.9530  0.027  0.0013
# 5   ...   0.900  0.10000       0  0.00240  0.0002  0.0000  0.000  0.0000
# 6   ...   0.960  0.04000       0  0.00200  0.0002  0.0000  0.000  0.0000
# 7   ...   0.002  0.00000       0  0.03000  0.0000  0.0000  0.820  0.0000
# 8   ...   0.850  0.15000       0  0.00000  0.0000  0.0000  0.000  0.0000
# 9   ...   0.850  0.15000       0  0.00003  0.0000  0.0000  0.000  0.0000
# 10  ...   0.000  0.00000       0  0.02000  0.0000  0.0800  0.900  0.0000
#
#          Ar  NaCl
# 0   0.00000  0.22
# 1   0.00007  0.00
# 2   0.00930  0.00
# 3   0.70000  0.01
# 4   0.01600  0.00
# 5   0.00000  0.00
# 6   0.00000  0.00
# 7   0.12000  0.00
# 8   0.00000  0.00
# 9   0.00000  0.00
# 10  0.00000  0.00
#
# [11 rows x 37 columns]

# %%
planets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 37 columns):
# name                           11 non-null object
# type                           11 non-null object
# mass_1024kg                    11 non-null float64
# diameter_km                    11 non-null float64
# density_kg_m3                  11 non-null int64
# gravity_m_s2                   11 non-null float64
# escape_vel_km_s                11 non-null float64
# rotation_period_hr             11 non-null float64
# day_len_hr                     11 non-null float64
# distance_from_sun_106 km       11 non-null float64
# perihelion_106 km              11 non-null float64
# aphelion_106 km                11 non-null float64
# orbital_period_days            11 non-null float64
# orbital_velocity_km_s          11 non-null float64
# orbital_inclination_degrees    11 non-null float64
# orbital_eccentricity           11 non-null float64
# obliquity_to_orbit_degrees     10 non-null float64
# mean_temp_c                    11 non-null int64
# surface_pressure_bars          11 non-null float64
# nbr_moons                      11 non-null int64
# rings                          11 non-null object
# magnetic_field                 10 non-null object
# equatorial_radius_km           11 non-null float64
# mean_radius_km                 11 non-null float64
# V(1,0) (mag)                   9 non-null float64
# geometric_albedo               10 non-null float64
# atmospheric_mass_kg            11 non-null float64
# H2                             11 non-null float64
# He                             11 non-null float64
# H2O                            11 non-null object
# CH4                            11 non-null float64
# NH3                            11 non-null float64
# CO2                            11 non-null float64
# N2                             11 non-null float64
# O2                             11 non-null float64
# Ar                             11 non-null float64
# NaCl                           11 non-null float64
# dtypes: float64(29), int64(3), object(5)
# memory usage: 3.3+ KB

# %%
planets.columns
# Out:
# Index(['name', 'type', 'mass_1024kg', 'diameter_km', 'density_kg_m3',
#        'gravity_m_s2', 'escape_vel_km_s', 'rotation_period_hr', 'day_len_hr',
#        'distance_from_sun_106 km', 'perihelion_106 km', 'aphelion_106 km',
#        'orbital_period_days', 'orbital_velocity_km_s',
#        'orbital_inclination_degrees', 'orbital_eccentricity',
#        'obliquity_to_orbit_degrees', 'mean_temp_c', 'surface_pressure_bars',
#        'nbr_moons', 'rings', 'magnetic_field', 'equatorial_radius_km',
#        'mean_radius_km', 'V(1,0) (mag)', 'geometric_albedo',
#        'atmospheric_mass_kg', 'H2', 'He', 'H2O', 'CH4', 'NH3', 'CO2', 'N2',
#        'O2', 'Ar', 'NaCl'],
#       dtype='object')

# %%
planets.loc[:, 'mass_1024kg':'atmospheric_mass_kg'].head()
# Out:
#    mass_1024kg  diameter_km  density_kg_m3  gravity_m_s2  escape_vel_km_s  \
# 0        0.330       4879.0           5427           3.7              4.3
# 1        4.870      12104.0           5243           8.9             10.4
# 2        5.970      12756.0           5514           9.8             11.2
# 3        0.073       3475.0           3340           1.6              2.4
# 4        0.642       6792.0           3933           3.7              5.0
#
#    rotation_period_hr  day_len_hr  distance_from_sun_106 km  \
# 0              1407.6      4222.6                      57.9
# 1             -5832.5      2802.0                     108.2
# 2                23.9        24.0                     149.6
# 3               655.7       708.7                     149.6
# 4                24.6        24.7                     227.9
#
#    perihelion_106 km  aphelion_106 km         ...          mean_temp_c  \
# 0               46.0             69.8         ...                  167
# 1              107.5            108.9         ...                  464
# 2              147.1            152.1         ...                   15
# 3              147.1            152.1         ...                  -20
# 4              206.6            249.2         ...                  -65
#
#    surface_pressure_bars  nbr_moons  rings  magnetic_field  \
# 0           1.000000e-14          0     No             Yes
# 1           9.200000e+01          0     No              No
# 2           1.014000e+00          1     No             Yes
# 3           3.000000e-15          0     No              No
# 4           1.000000e-02          2     No              No
#
#    equatorial_radius_km  mean_radius_km  V(1,0) (mag) geometric_albedo  \
# 0             2440.5300       2439.4000         -0.60            0.106
# 1             6051.8000       6051.8000         -4.47            0.650
# 2             6378.1366       6371.0084         -3.86            0.367
# 3             1737.5000       1737.4000           NaN              NaN
# 4             3396.1900       3389.5000         -1.52            0.150
#
#   atmospheric_mass_kg
# 0        1.000000e+03
# 1        4.800000e+20
# 2        1.400000e+21
# 3        1.000000e+05
# 4        2.500000e+16
#
# [5 rows x 25 columns]

# %%
feature_list1 = ['mass_1024kg', 'diameter_km', 'density_kg_m3', 'gravity_m_s2', 'mean_temp_c', 'surface_pressure_bars', 'magnetic_field', 'atmospheric_mass_kg']

# %%
sns.pairplot(planets[feature_list1])

# %%
sns.relplot(x='mass_1024kg', y='diameter_km', data=planets, kind='scatter', height=6, aspect=1.8)

# %%
l_plot = sns.relplot(x='mass_1024kg', y='diameter_km', data=planets, kind='scatter', height=6, aspect=1.8)
l_plot.set(xscale='log', yscale='log')

# %%
mod_plot = sns.regplot(x='mass_1024kg', y='diameter_km', data=planets, logx=True)
# Out:
# C:\Users\Julie\Anaconda3\lib\site-packages\seaborn\regression.py:279: RuntimeWarning: invalid value encountered in log
#   grid = np.c_[np.ones(len(grid)), np.log(grid)]

# %%
l_plot = sns.relplot(x='mass_1024kg', y='diameter_km', data=planets, kind='scatter', height=8, aspect=1.6, size='gravity_m_s2')
l_plot.set(xscale='log', yscale='log')

# %%
sns.lmplot(x='mass_1024kg', y='diameter_km', data=planets)

# %%
sns.lmplot(x='mass_1024kg', y='diameter_km', data=planets[planets['type'] == 'planet'])

# %%
sns.lmplot(x='mass_1024kg', y='diameter_km', data=planets, lowess=True)

# %%
sns.lmplot(x='mass_1024kg', y='diameter_km', data=planets, hue='type')

# %%
sns.lmplot(x='mass_1024kg', y='diameter_km', data=planets, hue='magnetic_field', col='type')

# %%
sns.lmplot(x='mass_1024kg', y='diameter_km', data=planets, row='magnetic_field', col='type')

# %%
planets['magnetic_field'].value_counts()
# Out:
# Yes    6
# No     4
# Name: magnetic_field, dtype: int64

# %%
planets.columns
# Out:
# Index(['name', 'type', 'mass_1024kg', 'diameter_km', 'density_kg_m3',
#        'gravity_m_s2', 'escape_vel_km_s', 'rotation_period_hr', 'day_len_hr',
#        'distance_from_sun_106 km', 'perihelion_106 km', 'aphelion_106 km',
#        'orbital_period_days', 'orbital_velocity_km_s',
#        'orbital_inclination_degrees', 'orbital_eccentricity',
#        'obliquity_to_orbit_degrees', 'mean_temp_c', 'surface_pressure_bars',
#        'nbr_moons', 'rings', 'magnetic_field', 'equatorial_radius_km',
#        'mean_radius_km', 'V(1,0) (mag)', 'geometric_albedo',
#        'atmospheric_mass_kg', 'H2', 'He', 'H2O', 'CH4', 'NH3', 'CO2', 'N2',
#        'O2', 'Ar', 'NaCl'],
#       dtype='object')

# %%
planets.head()
# Out:
#         name    type  mass_1024kg  diameter_km  density_kg_m3  gravity_m_s2  \
# 0   Mercury   planet        0.330       4879.0           5427           3.7
# 1     Venus   planet        4.870      12104.0           5243           8.9
# 2     Earth   planet        5.970      12756.0           5514           9.8
# 3      Moon     moon        0.073       3475.0           3340           1.6
# 4      Mars   planet        0.642       6792.0           3933           3.7
#
#    escape_vel_km_s  rotation_period_hr  day_len_hr  distance_from_sun_106 km  \
# 0              4.3              1407.6      4222.6                      57.9
# 1             10.4             -5832.5      2802.0                     108.2
# 2             11.2                23.9        24.0                     149.6
# 3              2.4               655.7       708.7                     149.6
# 4              5.0                24.6        24.7                     227.9
#
#    ...     H2       He     H2O  CH4  NH3     CO2     N2      O2       Ar  NaCl
# 0  ...   0.22  0.06000       0  0.0  0.0  0.0000  0.000  0.4200  0.00000  0.22
# 1  ...   0.00  0.00002   2e-05  0.0  0.0  0.9650  0.035  0.0000  0.00007  0.00
# 2  ...   0.00  0.00000  0-0.04  0.0  0.0  0.0003  0.781  0.2090  0.00930  0.00
# 3  ...   0.00  0.29000       0  0.0  0.0  0.0000  0.000  0.0000  0.70000  0.01
# 4  ...   0.00  0.00000   3e-05  0.0  0.0  0.9530  0.027  0.0013  0.01600  0.00
#
# [5 rows x 37 columns]

# %%
sns.jointplot(x='mass_1024kg', y='diameter_km', data=planets, kind='kde')

# %%
sns.jointplot(x='density_kg_m3', y='gravity_m_s2', data=planets, kind='kde')

# %%
sns.jointplot(x='density_kg_m3', y='gravity_m_s2', data=planets, kind='reg')

# %%
sns.pairplot(planets, x_vars=['mass_1024kg', 'density_kg_m3'], y_vars=['gravity_m_s2', 'diameter_km'], height=5, kind='reg')

# %%
sns.pairplot(planets, x_vars=['mass_1024kg', 'density_kg_m3'], y_vars=['gravity_m_s2', 'diameter_km'], height=5, kind='reg', hue='magnetic_field')
