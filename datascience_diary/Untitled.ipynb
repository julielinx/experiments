# %%
planets_top_feat = planets[features]

# %%
planets_top_feat.corr()
# Out:
#                              atmospheric_mass_kg  diameter_km  mean_radius_km  \
# atmospheric_mass_kg                     1.000000     0.862912        0.864138
# diameter_km                             0.862912     1.000000        0.999945
# mean_radius_km                          0.864138     0.999945        1.000000
# equatorial_radius_km                    0.862915     1.000000        0.999945
# escape_vel_km_s                         0.910232     0.971194        0.973155
# mass_1024kg                             0.999894     0.868751        0.869872
# day_len_hr                             -0.242968    -0.352086       -0.353254
# V(1,0) (mag)                           -0.570149    -0.756907       -0.758661
# surface_pressure_bars                  -0.003563     0.461183        0.462824
# rings                                   0.577273     0.849219        0.852419
# gravity_m_s2                            0.843291     0.811898        0.816135
# ...

# %%
plt.figure(figsize=(12,10))
sns.heatmap(planets_top_feat.corr())

# %%
planets_top_feat.corr(method='spearman')
# Out:
#                              atmospheric_mass_kg  V(1,0) (mag)  diameter_km  \
# atmospheric_mass_kg                     1.000000     -0.966667     0.945455
# V(1,0) (mag)                           -0.966667      1.000000    -0.966667
# diameter_km                             0.945455     -0.966667     1.000000
# mean_radius_km                          0.945455     -0.966667     1.000000
# equatorial_radius_km                    0.945455     -0.966667     1.000000
# escape_vel_km_s                         0.918182     -0.950000     0.981818
# mass_1024kg                             0.918182     -0.950000     0.981818
# day_len_hr                             -0.881818      0.883333    -0.818182
# surface_pressure_bars                   0.853247     -0.813676     0.816548
# rings                                   0.836660     -0.866025     0.836660
# gravity_m_s2                            0.815492     -0.753145     0.865606
# ...

# %%
plt.figure(figsize=(12,10))
sns.heatmap(planets_top_feat.corr(method='spearman'))

# %%
plt.figure(figsize=(20,8))

plt.subplot(1, 2, 1)
sns.heatmap(planets_top_feat.corr())
plt.title('Pearson correlations')
plt.subplot(1, 2, 2)
sns.heatmap(planets_top_feat.corr(method='spearman'))
plt.title('Spearman correlations')

plt.show()

# %%
sorted_features = feature_corr.sort_values('abs_spearman', ascending=False).iloc[:21,:].sort_values('spearman_cor', ascending=False)['index'].tolist()
sorted_planets_top_feat = planets[sorted_features]

# %%
plt.figure(figsize=(20,8))

plt.subplot(1, 2, 1)
sns.heatmap(sorted_planets_top_feat.corr())
plt.title('Pearson correlations')
plt.subplot(1, 2, 2)
sns.heatmap(sorted_planets_top_feat.corr(method='spearman'))
plt.title('Spearman correlations')

plt.show()

# %%
selected_features = feature_corr.sort_values('abs_spearman', ascending=False).iloc[:21,:].sort_values('spearman_cor', ascending=False)['index'].tolist()
selected_features
# Out:
# ['atmospheric_mass_kg',
#  'diameter_km',
#  'mean_radius_km',
#  'equatorial_radius_km',
#  'escape_vel_km_s',
#  'mass_1024kg',
#  'surface_pressure_bars',
#  'rings',
#  'gravity_m_s2',
#  'nbr_moons',
#  'geometric_albedo',
#  'magnetic_field',
#  'type',
#  'orbital_period_days',
#  'perihelion_106\xa0km',
#  'orbital_eccentricity',
#  'rotation_period_hr',
#  'orbital_inclination_degrees',
#  'density_kg_m3',
#  'day_len_hr',
#  'V(1,0) (mag)']

# %%
sel_features = [e for e in selected_features if e not in ('diameter_km', 'mean_radius_km', 'equatorial_radius_km')]
sel_features
# Out:
# ['atmospheric_mass_kg',
#  'escape_vel_km_s',
#  'mass_1024kg',
#  'surface_pressure_bars',
#  'rings',
#  'gravity_m_s2',
#  'nbr_moons',
#  'geometric_albedo',
#  'magnetic_field',
#  'type',
#  'orbital_period_days',
#  'perihelion_106\xa0km',
#  'orbital_eccentricity',
#  'rotation_period_hr',
#  'orbital_inclination_degrees',
#  'density_kg_m3',
#  'day_len_hr',
#  'V(1,0) (mag)']

# %%
planets_sel_feat = planets[sel_features]

# %%
plt.figure(figsize=(20,8))

plt.subplot(1, 2, 1)
sns.heatmap(planets_sel_feat.corr())
plt.title('Pearson correlations')
plt.subplot(1, 2, 2)
sns.heatmap(planets_sel_feat.corr(method='spearman'))
plt.title('Spearman correlations')

plt.show()

# %%
correlation_matrix = sorted_planets_top_feat.corr(method='spearman')
collinear_features = set()
for i in range(len(correlation_matrix.columns)):
    sliced_matrix = correlation_matrix.iloc[i, :i]
    if sum(sliced_matrix[abs(sliced_matrix) > 0.9]):
        colname = correlation_matrix.columns[i]
        collinear_features.add(colname)

# %%
collinear_features
# Out:
# {'V(1,0) (mag)',
#  'day_len_hr',
#  'diameter_km',
#  'equatorial_radius_km',
#  'escape_vel_km_s',
#  'gravity_m_s2',
#  'mass_1024kg',
#  'mean_radius_km'}

# %%
noncoll_features = [f for f in sorted_planets_top_feat.columns.tolist() if f not in (collinear_features)]
noncoll_planets = sorted_planets_top_feat[noncoll_features]

plt.figure(figsize=(20,8))

plt.subplot(1, 2, 1)
sns.heatmap(noncoll_planets.corr())
plt.title('Pearson correlations')
plt.subplot(1, 2, 2)
sns.heatmap(noncoll_planets.corr(method='spearman'))
plt.title('Spearman correlations')

plt.show()
