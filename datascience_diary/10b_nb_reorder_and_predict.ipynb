# %% [markdown]
# # Entry 10 - Reorder Pre-processing and Make Prediction

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn')

from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
import category_encoders as ce


from sklearn.compose import ColumnTransformer
# from sklearn.datasets import fetch_openml
from sklearn.pipeline import Pipeline
# from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, #OneHotEncoder
# from sklearn.linear_model import LogisticRegression
# from sklearn.model_selection import train_test_split, GridSearchCV

# %% [markdown]
# ### Custom functions

# %%
def feature_corr(df, target, corr_type='spearman'):
    target_corr = pd.DataFrame(df.corrwith(target, axis=0, method=corr_type).reset_index()).rename(columns={0:corr_type})
    target_corr['abs'] = target_corr[corr_type].abs()
    top_features = target_corr[target_corr['abs'] >= 0.5].sort_values('abs', ascending=False)['index'].tolist()
    df_top = df[top_features]
    feature_corr = df_top.corr(method=corr_type)
    return df_top, feature_corr

# %%
def feature_coll(correlation_matrix, df_top):
    collinear_features = set()
    for i in range(len(correlation_matrix.columns)):
        sliced_matrix = correlation_matrix.iloc[i, :i]
        if sum(sliced_matrix[abs(sliced_matrix) > 0.9]):
            colname = correlation_matrix.columns[i]
            collinear_features.add(colname)
    collinear_features = list(collinear_features)
    print('Collinear features:', collinear_features)
    df = df_top.drop(collinear_features, axis=1)
    return df

# %%
def preprocess_data(df, scaler=StandardScaler(), encoder=ce.OrdinalEncoder):
    cat_features = df.select_dtypes('object').columns.tolist()
    num_features = df.select_dtypes('number').columns.tolist()
    
    cat_encoder = encoder(cols=cat_features)
    df = cat_encoder.fit_transform(df)
    columns = df.columns.tolist()
    index = df.index.tolist()
    df = scaler.fit_transform(df)
    df = pd.DataFrame(df, columns=columns, index=index)
    return scaler, cat_encoder, df

# stdz_scaler, cat_encoder, stdz_df = preprocess_data(raw_df)
# planets = stdz_df.loc[:, 'type':'atmospheric_mass_kg']
# planets

# %%
index = planets.index.tolist()
scaler = StandardScaler()
num_features = planets.select_dtypes('number').columns.tolist()
pd.DataFrame(scaler.fit_transform(planets[num_features]), columns=num_features, index=index)
# Out:
#          mass_1024kg  diameter_km  density_kg_m3  gravity_m_s2  \
# Mercury    -0.442264    -0.681977       1.429504     -0.606357
# Venus      -0.433970    -0.530590       1.323681      0.241653
# Earth      -0.431961    -0.516928       1.479540      0.388424
# Moon       -0.442733    -0.711396       0.229214     -0.948822
# Mars       -0.441694    -0.641894       0.570264     -0.606357
# Jupiter     3.024239     2.211778      -0.929091      2.557372
# Saturn      0.594708     1.741418      -1.296597      0.257961
# Titan      -0.442636    -0.676311      -0.609321     -0.981438
# Uranus     -0.284308     0.286882      -0.960723      0.209037
# Neptune    -0.256541     0.253567      -0.749652      0.584119
# Pluto      -0.442840    -0.734549      -0.486819     -1.095593
#
#          escape_vel_km_s  rotation_period_hr  day_len_hr  \
# Mercury        -0.686002            0.959204    2.568170
# Venus          -0.331100           -3.070742    1.514217
# Earth          -0.284556            0.189016   -0.546799
# Moon           -0.796545            0.540685   -0.038815
# Mars           -0.645276            0.189406   -0.546279
# Jupiter         2.525566            0.181224   -0.557259
# Saturn          1.129232            0.181669   -0.556666
# Titan          -0.784909            0.388340   -0.281196
# Uranus          0.303068            0.166139   -0.551843
# Neptune         0.431065            0.184675   -0.552660
# Pluto          -0.860544            0.090384   -0.450870
#
#          distance_from_sun_106_km  perihelion_106 km  aphelion_106 km  ...  \
# Mercury                 -0.809602          -0.855100        -0.762454  ...
# Venus                   -0.783215          -0.817084        -0.744951  ...
# Earth                   -0.761496          -0.792606        -0.725612  ...
# Moon                    -0.761496          -0.792606        -0.725612  ...
# Mars                    -0.720419          -0.755826        -0.682144  ...
# Jupiter                 -0.431520          -0.425797        -0.428140  ...
# Saturn                  -0.087957          -0.047429        -0.115717  ...
# Titan                   -0.087957          -0.047429        -0.115717  ...
# Uranus                   0.666948           0.810993         0.550897  ...
# Neptune                  1.518170           1.863822         1.241237  ...
# Pluto                    2.258544           1.859062         2.508211  ...
#
#          orbital_eccentricity  obliquity_to_orbit_degrees  mean_temp_c  \
# Mercury              1.741370                   -0.823535     1.083267
# Venus               -0.890624                    2.320273     2.605431
# Earth               -0.757695                   -0.409373     0.304247
# Moon                -0.252565                   -0.705380     0.124867
# Mars                 0.265858                   -0.377468    -0.105764
# Jupiter             -0.332322                   -0.769190    -0.336395
# Saturn              -0.225979                   -0.350880    -0.490149
# Titan               -0.598180                   -0.818465    -0.690029
# Uranus              -0.372201                    0.909365    -0.772031
# Neptune             -0.837453                   -0.322520    -0.797657
# Pluto                2.259793                    1.347172    -0.925785
#
#          surface_pressure_bars  nbr_moons  equatorial_radius_km  \
# Mercury              -0.638729  -0.636013             -0.681959
# Venus                -0.429988  -0.636013             -0.530622
# Earth                -0.636428  -0.602698             -0.516946
# Moon                 -0.638729  -0.636013             -0.711421
# Mars                 -0.638706  -0.569383             -0.641910
# Jupiter              -0.634191   1.995870              2.211788
# Saturn                1.630200   2.095815              1.741423
# Titan                -0.635099  -0.636013             -0.676337
# Uranus                1.630200   0.263491              0.286869
# Neptune               1.630200  -0.169604              0.253553
# Pluto                -0.638729  -0.469438             -0.734437
#
#          mean_radius_km  V(1,0) (mag)  geometric_albedo  atmospheric_mass_kg
# Mercury       -0.685450      1.224812         -1.374401            -0.436378
# Venus         -0.529849      0.075589          1.732669            -0.436377
# Earth         -0.516099      0.256733          0.116307            -0.436375
# Moon          -0.715688      1.379230         -1.294440            -0.436378
# Mars          -0.644525      0.951612         -1.123094            -0.436378
# Jupiter        2.220835     -1.388408          0.990171             3.036693
# Saturn         1.717771     -1.233991          0.704595             0.550706
# Titan         -0.679622     -1.002364         -0.780402            -0.436377
# Uranus         0.301922     -0.732134          0.933056            -0.279175
# Neptune        0.270047     -0.637107          0.361903            -0.253584
# Pluto         -0.739340      1.106029         -0.266365            -0.436378
#
# [11 rows x 23 columns]

# %%
def preprocess_data(df, scaler=StandardScaler(), encoder=ce.OrdinalEncoder):
    index = df.index.tolist()
    
    num_features = df.select_dtypes('number').columns.tolist()    
    num_scale = scaler.fit_transform(df[num_features])
    num_df = pd.DataFrame(num_scale, columns=num_features, index=index)
    
    cat_features = df.select_dtypes('object').columns.tolist()
    cat_encoder = encoder(cols=cat_features)
    cat_encode = cat_encoder.fit_transform(df[cat_features])
    cat_df = pd.DataFrame(cat_encode, columns=cat_features, index=index)

# %%
df = X_train.copy()

index = df.index.tolist()

num_features = df.select_dtypes('number').columns.tolist()
num_scale = scaler.fit_transform(df[num_features])
num_df = pd.DataFrame(num_scale, columns=num_features, index=index)

# %%
num_features
# Out:
# ['diameter_km',
#  'density_kg_m3',
#  'gravity_m_s2',
#  'escape_vel_km_s',
#  'rotation_period_hr',
#  'day_len_hr',
#  'distance_from_sun_106_km',
#  'perihelion_106\xa0km',
#  'aphelion_106\xa0km',
#  'orbital_period_days',
#  'orbital_velocity_km_s',
#  'orbital_inclination_degrees',
#  'orbital_eccentricity',
#  'obliquity_to_orbit_degrees',
#  'mean_temp_c',
#  'surface_pressure_bars',
#  'nbr_moons',
#  'equatorial_radius_km',
#  'mean_radius_km',
#  'V(1,0) (mag)',
#  'geometric_albedo',
#  'atmospheric_mass_kg']

# %%
num_scale
# Out:
# array([[-0.68197725,  1.4295041 , -0.6063566 , -0.68600203,  0.95920392,
#          2.5681697 , -0.80960212, -0.85510048, -0.76245439, -0.61412582,
#          2.12770588,  0.69069669,  1.7413697 , -0.82353459,  1.08326682,
#         -0.63872894, -0.63601331, -0.68195941, -0.68545025,  1.22481202,
#         -1.37440101, -0.43637751],
#        [-0.53058968,  1.32368075,  0.24165312, -0.33110044, -3.07074188,
#          1.51421747, -0.78321454, -0.8170844 , -0.74495079, -0.60942549,
#          1.27109702, -0.07545426, -0.8906242 ,  2.3202734 ,  2.60543141,
#         -0.42998752, -0.63601331, -0.53062153, -0.52984903,  0.07558902,
#          1.7326695 , -0.43637663],
#        [-0.51692813,  1.47954014,  0.38842403, -0.28455597,  0.18901622,
#         -0.54679851, -0.76149594, -0.79260576, -0.72561178, -0.6045945 ,
#          0.91187395, -0.79904127, -0.75769521, -0.40937281,  0.30424655,
#         -0.63642825, -0.60269833, -0.51694571, -0.51609939,  0.25673269,
#          0.11630745, -0.43637495],
#        [-0.71139568,  0.22921422, -0.94882206, -0.79654515,  0.54068536,
#         -0.03881519, -0.76149594, -0.79260576, -0.72561178, -0.61621295,
#         -1.07766921,  0.28633924, -0.25256507, -0.7053799 ,  0.12486688,
#         -0.63872894, -0.63601331, -0.71142136, -0.71568833,  1.37922958,
#         -1.29443963, -0.43637751],
#        [-0.64189359,  0.57026448, -0.6063566 , -0.64527562,  0.18940585,
#         -0.54627917, -0.72041945, -0.75582597, -0.68214377, -0.59352963,
#          0.5181102 , -0.39468382,  0.26585797, -0.37746785, -0.10576411,
#         -0.63870626, -0.56938335, -0.64191046, -0.64452546,  0.95161172,
#         -1.12309383, -0.43637751],
#        [ 2.21177786, -0.9290914 ,  2.55737197,  2.52556645,  0.18122361,
#         -0.55725939, -0.43152009, -0.42579695, -0.42814017, -0.4682333 ,
#         -0.24178476, -0.52237565, -0.33232246, -0.76918981, -0.33639511,
#         -0.63419109,  1.99587035,  2.21178795,  2.22083452, -1.38840825,
#          0.99017103,  3.0366931 ],
#        [ 1.74141824, -1.2965975 ,  0.257961  ,  1.12923233,  0.1816689 ,
#         -0.55666586, -0.087957  , -0.04742878, -0.11571664, -0.24762374,
#         -0.47666138, -0.266992  , -0.22597927, -0.35088039, -0.49014911,
#          1.63019953,  2.0958153 ,  1.74142258,  1.71777101, -1.23399069,
#          0.7045947 ,  0.55070572],
#        [-0.67631148, -0.60932083, -0.98143782, -0.78490903,  0.38833993,
#         -0.28119601, -0.087957  , -0.04742878, -0.11571664, -0.61660149,
#         -0.75989496, -0.73519536, -0.59818043, -0.81846524, -0.69002931,
#         -0.63509866, -0.63601331, -0.67633673, -0.67962231, -1.00236435,
#         -0.78040223, -0.4363775 ],
#        [ 0.28688226, -0.96072338,  0.20903736,  0.30306797,  0.16613936,
#         -0.55184347,  0.66694801,  0.81099284,  0.55089732,  0.43462923,
#         -0.67699733, -0.6287855 , -0.37220116,  0.90936536, -0.77203145,
#          1.63019953,  0.26349123,  0.28686879,  0.30192226, -0.73213361,
#          0.93305576, -0.27917537],
#        [ 0.25356652, -0.7496518 ,  0.58411858,  0.43106527,  0.18467462,
#         -0.55265957,  1.51817029,  1.86382189,  1.24123738,  1.43902855,
#         -0.77371123, -0.41596579, -0.8374526 , -0.32252043, -0.79765711,
#          1.63019953, -0.16960355,  0.25355264,  0.27004736, -0.63710742,
#          0.3619031 , -0.25358432],
#        [-0.73454907, -0.4868188 , -1.09559298, -0.86054379,  0.0903841 ,
#         -0.45087001,  2.25854377,  1.85906216,  2.50821127,  2.49668913,
#         -0.82206818,  2.86145772,  2.25979274,  1.34717225, -0.92578545,
#         -0.63872892, -0.4694384 , -0.73443675, -0.73934037,  1.10602928,
#         -0.26636483, -0.43637751]])

# %%
num_df
# Out:
#          diameter_km  density_kg_m3  gravity_m_s2  escape_vel_km_s  \
# Mercury    -0.681977       1.429504     -0.606357        -0.686002
# Venus      -0.530590       1.323681      0.241653        -0.331100
# Earth      -0.516928       1.479540      0.388424        -0.284556
# Moon       -0.711396       0.229214     -0.948822        -0.796545
# Mars       -0.641894       0.570264     -0.606357        -0.645276
# Jupiter     2.211778      -0.929091      2.557372         2.525566
# Saturn      1.741418      -1.296597      0.257961         1.129232
# Titan      -0.676311      -0.609321     -0.981438        -0.784909
# Uranus      0.286882      -0.960723      0.209037         0.303068
# Neptune     0.253567      -0.749652      0.584119         0.431065
# Pluto      -0.734549      -0.486819     -1.095593        -0.860544
#
#          rotation_period_hr  day_len_hr  distance_from_sun_106_km  \
# Mercury            0.959204    2.568170                 -0.809602
# Venus             -3.070742    1.514217                 -0.783215
# Earth              0.189016   -0.546799                 -0.761496
# Moon               0.540685   -0.038815                 -0.761496
# Mars               0.189406   -0.546279                 -0.720419
# Jupiter            0.181224   -0.557259                 -0.431520
# Saturn             0.181669   -0.556666                 -0.087957
# Titan              0.388340   -0.281196                 -0.087957
# Uranus             0.166139   -0.551843                  0.666948
# Neptune            0.184675   -0.552660                  1.518170
# Pluto              0.090384   -0.450870                  2.258544
#
#          perihelion_106 km  aphelion_106 km  orbital_period_days  ...  \
# Mercury          -0.855100        -0.762454            -0.614126  ...
# Venus            -0.817084        -0.744951            -0.609425  ...
# Earth            -0.792606        -0.725612            -0.604594  ...
# Moon             -0.792606        -0.725612            -0.616213  ...
# Mars             -0.755826        -0.682144            -0.593530  ...
# Jupiter          -0.425797        -0.428140            -0.468233  ...
# Saturn           -0.047429        -0.115717            -0.247624  ...
# Titan            -0.047429        -0.115717            -0.616601  ...
# Uranus            0.810993         0.550897             0.434629  ...
# Neptune           1.863822         1.241237             1.439029  ...
# Pluto             1.859062         2.508211             2.496689  ...
#
#          orbital_eccentricity  obliquity_to_orbit_degrees  mean_temp_c  \
# Mercury              1.741370                   -0.823535     1.083267
# Venus               -0.890624                    2.320273     2.605431
# Earth               -0.757695                   -0.409373     0.304247
# Moon                -0.252565                   -0.705380     0.124867
# Mars                 0.265858                   -0.377468    -0.105764
# Jupiter             -0.332322                   -0.769190    -0.336395
# Saturn              -0.225979                   -0.350880    -0.490149
# Titan               -0.598180                   -0.818465    -0.690029
# Uranus              -0.372201                    0.909365    -0.772031
# Neptune             -0.837453                   -0.322520    -0.797657
# Pluto                2.259793                    1.347172    -0.925785
#
#          surface_pressure_bars  nbr_moons  equatorial_radius_km  \
# Mercury              -0.638729  -0.636013             -0.681959
# Venus                -0.429988  -0.636013             -0.530622
# Earth                -0.636428  -0.602698             -0.516946
# Moon                 -0.638729  -0.636013             -0.711421
# Mars                 -0.638706  -0.569383             -0.641910
# Jupiter              -0.634191   1.995870              2.211788
# Saturn                1.630200   2.095815              1.741423
# Titan                -0.635099  -0.636013             -0.676337
# Uranus                1.630200   0.263491              0.286869
# Neptune               1.630200  -0.169604              0.253553
# Pluto                -0.638729  -0.469438             -0.734437
#
#          mean_radius_km  V(1,0) (mag)  geometric_albedo  atmospheric_mass_kg
# Mercury       -0.685450      1.224812         -1.374401            -0.436378
# Venus         -0.529849      0.075589          1.732669            -0.436377
# Earth         -0.516099      0.256733          0.116307            -0.436375
# Moon          -0.715688      1.379230         -1.294440            -0.436378
# Mars          -0.644525      0.951612         -1.123094            -0.436378
# Jupiter        2.220835     -1.388408          0.990171             3.036693
# Saturn         1.717771     -1.233991          0.704595             0.550706
# Titan         -0.679622     -1.002364         -0.780402            -0.436377
# Uranus         0.301922     -0.732134          0.933056            -0.279175
# Neptune        0.270047     -0.637107          0.361903            -0.253584
# Pluto         -0.739340      1.106029         -0.266365            -0.436378
#
# [11 rows x 22 columns]

# %%
encoder=ce.OrdinalEncoder

cat_features = df.select_dtypes('object').columns.tolist()
cat_encoder = encoder(cols=cat_features)
cat_encode = cat_encoder.fit_transform(df[cat_features])
cat_df = pd.DataFrame(cat_encode, columns=cat_features, index=index)

# %%
cat_features
# Out:
# ['type', 'rings', 'magnetic_field']

# %%
cat_encoder
# Out:
# OrdinalEncoder(cols=['type', 'rings', 'magnetic_field'], drop_invariant=False,
#                handle_missing='value', handle_unknown='value',
#                mapping=[{'col': 'type', 'data_type': dtype('O'),
#                          'mapping': planet    1
# moon      2
# dwarf     3
# NaN      -2
# dtype: int64},
#                         {'col': 'rings', 'data_type': dtype('O'),
#                          'mapping': No     1
# Yes    2
# NaN   -2
# dtype: int64},
#                         {'col': 'magnetic_field', 'data_type': dtype('O'),
#                          'mapping': Yes    1
# No     2
# NaN   -2
# dtype: int64}],
#                return_df=True, verbose=0)

# %%
cat_encode
# Out:
#          type  rings  magnetic_field
# name
# Mercury     1      1               1
# Venus       1      1               2
# Earth       1      1               1
# Moon        2      1               2
# Mars        1      1               2
# Jupiter     1      2               1
# Saturn      1      2               1
# Titan       2      1               2
# Uranus      1      2               1
# Neptune     1      2               1
# Pluto       3      1               2

# %%
cat_df
# Out:
#          type  rings  magnetic_field
# Mercury     1      1               1
# Venus       1      1               2
# Earth       1      1               1
# Moon        2      1               2
# Mars        1      1               2
# Jupiter     1      2               1
# Saturn      1      2               1
# Titan       2      1               2
# Uranus      1      2               1
# Neptune     1      2               1
# Pluto       3      1               2

# %%
def convert_categoricals(df):
    cat_vars = df.select_dtypes('object').columns.tolist()
    converted = df.copy()
    converted[cat_vars] = df[cat_vars].astype('category')
    for cat in cat_vars:
        converted[cat] = converted[cat].cat.codes
    return converted

# %%
def feature_stdz(df, scaler = StandardScaler()):
    columns = df.columns.tolist()
    index = df.index.tolist()
    stdz_df = scaler.fit_transform(df)
    stdz_df = pd.DataFrame(stdz_df, columns=columns, index=index)
    return stdz_df

# %% [markdown]
# ### Get and 'split' data
#
# The 'split' portion is currently a cheating version where I just create two new rows because I decided not to split it into train and test sets for this tiny dataset. But I want a placeholder so I don't forget to incorporate it in the next iteration when I start using bigger datasets.

# %%
planets = pd.read_excel('data/planets_moons.xlsx', index_col=0)
planets
# Out:
#            type  mass_1024kg  diameter_km  density_kg_m3  gravity_m_s2  \
# name
# Mercury  planet       0.3300       4879.0           5427           3.7
# Venus    planet       4.8700      12104.0           5243           8.9
# Earth    planet       5.9700      12756.0           5514           9.8
# Moon       moon       0.0730       3475.0           3340           1.6
# Mars     planet       0.6420       6792.0           3933           3.7
# Jupiter  planet    1898.0000     142984.0           1326          23.1
# Saturn   planet     568.0000     120536.0            687           9.0
# Titan      moon       0.1260       5149.4           1882           1.4
# Uranus   planet      86.8000      51118.0           1271           8.7
# Neptune  planet     102.0000      49528.0           1638          11.0
# Pluto     dwarf       0.0146       2370.0           2095           0.7
#
#          escape_vel_km_s  rotation_period_hr  day_len_hr  \
# name
# Mercury              4.3              1407.6      4222.6
# Venus               10.4             -5832.5      2802.0
# Earth               11.2                23.9        24.0
# Moon                 2.4               655.7       708.7
# Mars                 5.0                24.6        24.7
# Jupiter             59.5                 9.9         9.9
# Saturn              35.5                10.7        10.7
# Titan                2.6               382.0       382.0
# Uranus              21.3               -17.2        17.2
# Neptune             23.5                16.1        16.1
# Pluto                1.3              -153.3       153.3
#
#          distance_from_sun_106_km  perihelion_106 km  ...  mean_temp_c  \
# name                                                  ...
# Mercury                      57.9               46.0  ...          167
# Venus                       108.2              107.5  ...          464
# Earth                       149.6              147.1  ...           15
# Moon                        149.6              147.1  ...          -20
# Mars                        227.9              206.6  ...          -65
# Jupiter                     778.6              740.5  ...         -110
# Saturn                     1433.5             1352.6  ...         -140
# Titan                      1433.5             1352.6  ...         -179
# Uranus                     2872.5             2741.3  ...         -195
# Neptune                    4495.1             4444.5  ...         -200
# Pluto                      5906.4             4436.8  ...         -225
#
#          surface_pressure_bars  nbr_moons  rings  magnetic_field  \
# name
# Mercury           1.000000e-14          0     No             Yes
# Venus             9.200000e+01          0     No              No
# Earth             1.014000e+00          1     No             Yes
# Moon              3.000000e-15          0     No              No
# Mars              1.000000e-02          2     No              No
# Jupiter           2.000000e+00         79    Yes             Yes
# Saturn            1.000000e+03         82    Yes             Yes
# Titan             1.600000e+00          0     No              No
# Uranus            1.000000e+03         27    Yes             Yes
# Neptune           1.000000e+03         14    Yes             Yes
# Pluto             1.000000e-05          5     No              No
#
#          equatorial_radius_km  mean_radius_km  V(1,0) (mag)  geometric_albedo  \
# name
# Mercury             2440.5300       2439.4000         -0.60             0.106
# Venus               6051.8000       6051.8000         -4.47             0.650
# Earth               6378.1366       6371.0084         -3.86             0.367
# Moon                1737.5000       1737.4000         -0.08             0.120
# Mars                3396.1900       3389.5000         -1.52             0.150
# Jupiter            71492.0000      69911.0000         -9.40             0.520
# Saturn             60268.0000      58232.0000         -8.88             0.470
# Titan               2574.7000       2574.7000         -8.10             0.210
# Uranus             25559.0000      25362.0000         -7.19             0.510
# Neptune            24764.0000      24622.0000         -6.87             0.410
# Pluto               1188.3000       1188.3000         -1.00             0.300
#
#         atmospheric_mass_kg
# name
# Mercury        1.000000e+03
# Venus          4.800000e+20
# Earth          1.400000e+21
# Moon           1.000000e+05
# Mars           2.500000e+16
# Jupiter        1.900000e+27
# Saturn         5.400000e+26
# Titan          9.100000e+18
# Uranus         8.600000e+25
# Neptune        1.000000e+26
# Pluto          1.300000e+14
#
# [11 rows x 26 columns]

# %%
# Creating the 'test' set that I'll be using to make a prediction

predict_on = planets.loc[['Mars'], :].drop('mass_1024kg', axis=1)
predict_on = pd.concat([predict_on]*2)
predict_on.index = ['Mars_low', 'Mars_high']
# Low end surface pressure based on conditions on Mt Everest
predict_on.loc['Mars_low', 'surface_pressure_bars'] = 0.47
# High end surface pressure based on nigrogen narcosis experienced by divers
predict_on.loc['Mars_high', 'surface_pressure_bars'] = 4
predict_on
# Out:
#              type  diameter_km  density_kg_m3  gravity_m_s2  escape_vel_km_s  \
# Mars_low   planet       6792.0           3933           3.7              5.0
# Mars_high  planet       6792.0           3933           3.7              5.0
#
#            rotation_period_hr  day_len_hr  distance_from_sun_106_km  \
# Mars_low                 24.6        24.7                     227.9
# Mars_high                24.6        24.7                     227.9
#
#            perihelion_106 km  aphelion_106 km  ...  mean_temp_c  \
# Mars_low               206.6            249.2  ...          -65
# Mars_high              206.6            249.2  ...          -65
#
#            surface_pressure_bars  nbr_moons  rings  magnetic_field  \
# Mars_low                    0.47          2     No              No
# Mars_high                   4.00          2     No              No
#
#            equatorial_radius_km  mean_radius_km  V(1,0) (mag)  \
# Mars_low                3396.19          3389.5         -1.52
# Mars_high               3396.19          3389.5         -1.52
#
#           geometric_albedo atmospheric_mass_kg
# Mars_low              0.15        2.500000e+16
# Mars_high             0.15        2.500000e+16
#
# [2 rows x 25 columns]

# %% [markdown]
# ### Separate the target value

# %%
X_train = planets.drop('mass_1024kg', axis=1)
y_train = planets['mass_1024kg']

# %% [markdown]
# ### Determine collinearity and narrow features

# %%
df_top, feature_corr = feature_corr(X_train, y_train)
non_coll = feature_coll(feature_corr, df_top)
non_coll_features = non_coll.columns.tolist()
# Out:
# Collinear features: ['gravity_m_s2', 'diameter_km', 'atmospheric_mass_kg', 'mean_radius_km', 'equatorial_radius_km', 'nbr_moons']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-2b30c50671cb> in <module>
#       6 # feature_coll(correlation_matrix, df_top)
#       7 noncoll = feature_coll(feature_corr, df_top)
# ----> 8 non_coll
#
# NameError: name 'non_coll' is not defined

# %%
planets_num = convert_categoricals(planets)

planets_stdz = feature_stdz(select_df)
planets_stdz

# %% [markdown]
# ### Missing values
#
# Look for missing values. As seen below, there are none in this dataset (hand curated, I got rid of them all). Will need to address in the future.

# %%
planets_stdz.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11 entries, Mercury to Pluto
# Data columns (total 13 columns):
# atmospheric_mass_kg            11 non-null float64
# diameter_km                    11 non-null float64
# mass_1024kg                    11 non-null float64
# V(1,0) (mag)                   11 non-null float64
# day_len_hr                     11 non-null float64
# surface_pressure_bars          11 non-null float64
# rings                          11 non-null float64
# geometric_albedo               11 non-null float64
# density_kg_m3                  11 non-null float64
# magnetic_field                 11 non-null float64
# orbital_inclination_degrees    11 non-null float64
# type                           11 non-null float64
# rotation_period_hr             11 non-null float64
# dtypes: float64(13)
# memory usage: 1.2+ KB

# %% [markdown]
# ## Train model

# %%
X = planets_stdz.drop('atmospheric_mass_kg', axis=1)
y = planets_stdz['atmospheric_mass_kg']
model = LinearRegression()

model.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model.coef_
# Out:
# array([ 0.14238478,  0.69706561,  0.0096957 ,  0.00509335, -0.32938854,
#         0.31222586, -0.03180231, -0.0297368 ,  0.0237083 , -0.00429627,
#        -0.00544434, -0.04911224])

# %%
model.score(X, y)
# Out:
# 1.0

# %% [markdown]
# ## Make Predictions

# %% [markdown]
# ### Create test set

# %%
predict_on = select_df.loc[['Mars'], :]
predict_on = pd.concat([predict_on]*2)
# predict_on = predict_on.loc[np.repeat(predict_on.index, 2)]
predict_on.index = ['Mars_low', 'Mars_high']
predict_on.loc['Mars_low', 'surface_pressure_bars'] = 0.47
# Based on pressure on Mt Everest
predict_on.loc['Mars_high', 'surface_pressure_bars'] = 4
# Based on nigrogen narcosis experienced by divers
predict_on
# Out:
#            atmospheric_mass_kg  diameter_km  mass_1024kg  V(1,0) (mag)  \
# Mars_low          2.500000e+16       6792.0        0.642         -1.52
# Mars_high         2.500000e+16       6792.0        0.642         -1.52
#
#            day_len_hr  surface_pressure_bars  rings  geometric_albedo  \
# Mars_low         24.7                   0.47      0              0.15
# Mars_high        24.7                   4.00      0              0.15
#
#            density_kg_m3  magnetic_field  orbital_inclination_degrees  type  \
# Mars_low            3933               0                          1.9     2
# Mars_high           3933               0                          1.9     2
#
#            rotation_period_hr
# Mars_low                 24.6
# Mars_high                24.6
